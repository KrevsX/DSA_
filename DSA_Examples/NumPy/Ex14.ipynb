# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cause='Chronic Diseases','Unitentional Injuries','Alzeihmerz','Infuenza and Pneumonia','Sepsis','Others'

percentile = [62,5,4,2,1,26]

# %%
plt.figure(figsize=(10,10))
explodes=(0.05,0,0,0,0,0)

plt.pie(percentile,labels=cause ,autopct='%1.1f%%',startangle=70)

plt.axis('equal')
plt.title('Ohio state - 2012')
plt.show()
