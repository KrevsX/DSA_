# %%
import  pandas as pd

# %%
df=pd.read_csv('population_total.csv')

# %%
df.columns
# Out:
# Index(['country', 'year', 'population'], dtype='object')

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(x='year', y='population', kind='scatter',legend=True)
# Out:
# <Axes: xlabel='year', ylabel='population'>

# %%
df.plot(title='Sample Plot', figsize=(15,10))
# Out:
# <Axes: title={'center': 'Sample Plot'}>
